# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Data/ai_jobs.csv')

# %%
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

# %%
df.columns

# %%
df.dtypes

# %%
df.head()

# %%
df.describe()

# %%
df.info()
